# %%
import time
import requests
import json
import pymongo
# producer
from kafka import KafkaProducer

producer = KafkaProducer(bootstrap_servers='localhost:9092')
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["sic-crawl"]
mycol = mydb['lomart']

# %%
import pandas as pd


df = pd.read_csv("data.csv", sep="*")
df
# Out:
#    id           name          desc   age
# 0   1   Nguyen Van A   Hoc, Sinh 1    23
# 1   2   Nguyen Van B    Hoc Sinh 2    23
# 2   3   Nguyen Van C    Hoc Sinh 3    23
# 3   4   Nguyen Van D    Hoc Sinh 4    23

# %%
def func_get_congigs_cities():
    url = "https://mocha.lozi.vn/v6.1/configs"
    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '50',
    'x-language': 'vi',
    'x-lozi-client': '1'
    }
    response = requests.request("GET", url, headers=headers, data=payload)
    data_json = json.loads(response.text)
    return data_json['data']['shippingAdministrations']


def func_get_congigs_countries():
    url = "https://mocha.lozi.vn/v6.1/configs"
    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '50',
    'x-language': 'vi',
    'x-lozi-client': '1'
    }
    response = requests.request("GET", url, headers=headers, data=payload)
    data_json = json.loads(response.text)
    return data_json['data']['countries']


def func_get_cates_from_cityid(cityId=50):
    url = f"https://mocha.lozi.vn/v6.1/categories?superCategoryId=1&cityId={cityId}"

    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '50',
    'x-lozi-client': '1'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    data_json = json.loads(response.text)
    return data_json['data']

# %%
def get_shop_info_summary(categoriesID, cityId, page, limit=24):
    url = f"https://mocha.lozi.vn/v6.1/search/eateries?categories={categoriesID}&limit={limit}&page={page}&superCategoryId=1&cityId={cityId}"

    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '1',
    'x-lozi-client': '1'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    data_json = json.loads(response.text)
    return data_json['data'], data_json['pagination']

# %%
def get_shop_full_info(slug):
    url = f"https://latte.lozi.vn/v1.2/eateries/slug:{slug}"

    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '50',
    'x-lozi-client': '1'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    data_json = json.loads(response.text)
    return data_json['data']

# %%
def get_menu_info(slug):
    url = f"https://mocha.lozi.vn/v6.1/eateries/slug:{slug}/menu"

    payload = {}
    headers = {
    'accept': '*/*',
    'accept-language': 'vi_VN',
    'origin': 'https://loship.vn',
    'priority': 'u=1, i',
    'referer': 'https://loship.vn/',
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'x-access-token': 'unknown',
    'x-city-id': '50',
    'x-language': 'vi',
    'x-lozi-client': '1'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    data_json = json.loads(response.text)
    return data_json['data']

# %%
# pipeline 
citites_configs = func_get_congigs_cities() # lấy thông tin các thành phố

# Vòng lặp các thành phố
for idx_city, city in enumerate(citites_configs):
    if city['city']['id'] != 1:
        continue
    print("City ID : ", city['city']['id'])
    print("City Name : ", city['city']['name'])
    print("City slug: ", city['city']['slug'])
    cates = func_get_cates_from_cityid(cityId=city['city']['id']) # lấy thông tin các ngành hàng

    # vòng lặp các ngành hàng trong 1 thành phố
    for cate in cates:
        print(cate['id'])

        # Tính xem xem là 1 ngành hàng có bao nhiêu trang (pages)
        _, data_pages = get_shop_info_summary(categoriesID=cate['id'], cityId=city['city']['id'], page=1, limit=24)
        pages = data_pages['total']//data_pages['limit'] + 1

        # vòng lặp toàn các trang trong 1 ngành hàng
        for num_page in range(0, pages):
            data_shops, _ = get_shop_info_summary(categoriesID=cate['id'], cityId=city['city']['id'], 
                                                  page=num_page, limit=24)
            
            document_shops = []
            # vòng lặp tất cả các quán ăn trong 1 trang (page)
            for i, shop in enumerate(data_shops):
                print(i ,"slug : ", shop['slug'])
                shop_info = get_shop_full_info(slug=shop['slug']) # lấy toàn bộ thông tin của 1 quán ăn theo thẻ slug
                menu_info = get_menu_info(slug=shop['slug']) # lấy toàn thông tin của menu 
                print("shop_info : ", shop_info)
                print("menu info : ", menu_info)
                print()

                # Thêm vào danh sách các quán ăn
                doc_shop = {
                    'city': city['city'],
                    'category': cate,  
                    'shop_info': shop_info,
                    'menu_info': menu_info, 
                    'createAt': time.time()
                }

                document_shops.append(doc_shop)
            
            # kiểm tra nếu có dữ liệu về quán ăn thì mới insert
            if len(document_shops) > 0:
                # lưu dữ liệu quán ăn
                x = mycol.insert_many(document_shops)
                print(x.inserted_ids)
                print(">>>>> Lưu trữ dữ liệu quán ăn thành công <<<<<")

                # đẩy dữ liệu lên kafka
                producer.send("sic-kafka", bytes(document_shops, 'utf-8'))
                print(">>>> Đẩy dữ liệu lên Kafka Thành công <<<<")
            break
        break
    break
# Out:
# City ID :  1
# City Name :  Hà Nội
# City slug:  ha-noi
# 1168
# 0 slug :  nom-viet-nem-nuong-nha-trang-nghia-tan-ha-noi-1714356397614038734
# shop_info :  {'_id': '2350681', 'id': 2350681, 'slug': 'nom-viet-nem-nuong-nha-trang-nghia-tan-ha-noi-1714356397614038734', 'name': 'NƠM VIỆT - NEM NƯỚNG NHA TRANG - NGHĨA TÂN', 'description': '', 'address': {'street': '106C4 Nghĩa Tân,  Cầu Giấy', 'quater': '', 'district': '', 'city': 'Hà Nội', 'short': '106C4 Nghĩa Tân,  Cầu Giấy', 'full': '106C4 Nghĩa Tân,  Cầu Giấy, Hà Nội'}, 'latitude': 0, 'longitude': 0, 'coords': [0, 0], 'geohash': '', 'avatar': 'https://tea-3.lozi.vn/v1/images/resized/b-1713891211-eatery-avatar-1714096341', 'avatarFileName': 'b-1713891211-eatery-avatar-1714096341', 'area': '', 'near': '', 'direction': '', 'phoneNumber': '0987186383', 'countryCode': '84', 'website': '', 'category': 'Ăn Trưa, Món Cuốn, Món Ăn Việt', 'categories': ['Ăn Trưa', 'Món Cuốn', 'Món Ăn Việt'], 'superCategory': 2, 'photos': ['https://tea-2.lozi.vn/v1/ship/resized/b-1713891211-nom-bo-kho-1714098403', 'https://tea-2.lozi.vn/v1/ship/resized/b-1713891211-chan-ga-rut-xuong-dam-xoai-1714098300', 'https://tea-4.lozi.vn/v1/ship/resized/b-1713891211-sua-gao-lut-1714099164', 'https://tea-2.lozi.vn/v1/ship/resized/b-1713891211-tra-chanh-1714099135'], 'operatingTime': [{'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'sun'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'mon'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'tue'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'wed'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'thu'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'fri'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'sat'}], 'operatingStatus': {'isOpening': True, 'isOpening24h': False, 'minutesUntilNextStatus': 592}, 'capacityInt': 0, 'capacity': '0', 'rating': 0, 'price': {'min': 0, 'max': 0}, 'priceCouple': 0, 'facebook': '', 'closed': False, 'ownedAt': '0001-01-01T00:00:00.000Z', 'ownedBy': '0', 'createdAt': '2024-04-23T16:53:31.883Z', 'createdBy': 9913641, 'updatedAt': '2024-05-04T14:50:10.031Z', 'updatedBy': 18258788, 'count': {'like': 0, 'dislike': 0, 'comment': 0, 'block': 0, 'video': 0, 'visit': 0, 'buyable': 0, 'nonBuyable': 0, 'view': 3275, 'foodImage': 0, 'menuImage': 0, 'spaceImage': 0, 'serviceImage': 0, 'food': 0, 'menu': 0, 'space': 0, 'managerBlock': 0, 'branch': 0, 'promotion': 0}, 'comments': [], 'isManager': False, 'cityId': 1, 'districtId': 0, 'lastActivity': '2024-05-04T14:50:10.005Z', 'isShipping': True, 'username': 'nemnuongnhatrangnomfoods', 'shippingService': {'id': 1, 'name': 'loship'}}
# menu info :  [{'id': 3899981, 'name': 'NEM NƯỚNG', 'eateryId': 2350681, 'isExtraGroupDish': False, 'isPinned': True, 'dishes': [{'id': 74568156, 'name': 'Nem Nướng Nha Trang', 'price': 42000, 'rawPrice': 42000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/b-1713891211-nem-nuong-nha-trang-1714096604', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/b-1713891211-nem-nuong-nha-trang-1714096604'], 'description': '', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74568157, 'name': 'Nem Lụi Huế', 'price': 46000, 'rawPrice': 46000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/b-1713891211-nem-lui-hue-1714096707', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/b-1713891211-nem-lui-hue-1714096707'], 'description': '', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74568168, 'name': 'Nem Que', 'price': 32000, 'rawPrice': 32000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/b-1713891211-nem
 'foodImage': 0, 'menuImage': 0, 'spaceImage': 0, 'serviceImage': 0, 'food': 0, 'menu': 0, 'space': 0, 'managerBlock': 0, 'branch': 0, 'promotion': 0}, 'comments': [], 'isManager': False, 'cityId': 1, 'districtId': 5, 'lastActivity': '2023-11-28T08:58:29.788Z', 'isShipping': True, 'username': 'bunocsuoncosaunguyenkhanhtoan', 'shippingService': {'id': 1, 'name': 'loship'}}
# ...
#
# 8 slug :  bun-oc-suon-co-sau-nguyen-van-loc-quan-ha-dong-ha-noi-1701161796677516876
# shop_info :  {'_id': '2346303', 'id': 2346303, 'slug': 'bun-oc-suon-co-sau-nguyen-van-loc-quan-ha-dong-ha-noi-1701161796677516876', 'name': 'Bún Ốc Sườn Cô Sáu - Nguyễn Văn Lộc', 'description': '', 'address': {'street': 'Phố Nguyễn Văn Lộc', 'quater': '', 'district': 'Quận Hà Đông', 'city': 'Hà Nội', 'short': 'Phố Nguyễn Văn Lộc, Quận Hà Đông', 'full': 'Phố Nguyễn Văn Lộc, Quận Hà Đông, Hà Nội'}, 'latitude': 20.9852523, 'longitude': 105.7856128, 'coords': [105.7856128, 20.9852523], 'geohash': '', 'avatar': 'https://tea-2.lozi.vn/v1/images/resized/bun-oc-suon-co-sau-nguyen-van-loc-quan-ha-dong-ha-noi-1701161796677516876-eatery-avatar-1701231166', 'avatarFileName': 'bun-oc-suon-co-sau-nguyen-van-loc-quan-ha-dong-ha-noi-1701161796677516876-eatery-avatar-1701231166', 'area': '', 'near': '', 'direction': '', 'phoneNumber': '0588233333', 'countryCode': '84', 'website': '', 'category': 'Bún Ốc, Ăn Trưa, Ăn Sáng', 'categories': ['Bún Ốc', 'Ăn Trưa', 'Ăn Sáng'], 'superCategory': 2, 'photos': ['https://tea-2.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-bo-0-1701232441', 'https://tea-2.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-0-1701231933', 'https://tea-4.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-0-1701232208', 'https://tea-1.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-suon-0-1701233197'], 'operatingTime': [{'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'sun'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'mon'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'tue'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'wed'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'thu'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'fri'}, {'start': '10:00 AM', 'finish': '8:00 PM', 'weekday': 'sat'}], 'operatingStatus': {'isOpening': True, 'isOpening24h': False, 'minutesUntilNextStatus': 592}, 'capacityInt': 0, 'capacity': '0', 'rating': 0, 'price': {'min': 0, 'max': 0}, 'priceCouple': 0, 'facebook': '', 'closed': False, 'ownedAt': '0001-01-01T00:00:00.000Z', 'ownedBy': '0', 'createdAt': '2023-11-28T08:56:36.700Z', 'createdBy': 14177292, 'updatedAt': '2023-11-29T04:16:35.894Z', 'updatedBy': 7874667, 'count': {'like': 0, 'dislike': 0, 'comment': 0, 'block': 0, 'video': 0, 'visit': 0, 'buyable': 0, 'nonBuyable': 0, 'view': 4301, 'foodImage': 0, 'menuImage': 0, 'spaceImage': 0, 'serviceImage': 0, 'food': 0, 'menu': 0, 'space': 0, 'managerBlock': 0, 'branch': 0, 'promotion': 0}, 'comments': [], 'isManager': False, 'cityId': 1, 'districtId': 268, 'lastActivity': '2023-11-28T08:56:36.692Z', 'isShipping': True, 'username': 'bunocsuoncosaunguyenvanloc1', 'shippingService': {'id': 1, 'name': 'loship'}}
# menu info :  [{'id': 3864923, 'name': 'MENU', 'eateryId': 2346303, 'isExtraGroupDish': False, 'isPinned': False, 'dishes': [{'id': 74085665, 'name': 'Bún Đặc Biệt', 'price': 72000, 'rawPrice': 72000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-dac-biet-0-1701233414', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-dac-biet-0-1701233414'], 'description': '( Đã bao gồm 5000đ tiền hộp', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085666, 'name': 'Bún Ốc Nhỏ', 'price': 40000, 'rawPrice': 40000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-0-1701231933', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-0-1701231933'], 'description': '( Đã bao gồm 5000đ tiền hộp )', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085662, 'name': 'Bún Ốc Nhỏ + Bò', 'price': 50000, 'rawPrice': 50000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-bo-0-1701232451', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-bo-0-1701232451'], 'description': '( Đã bao gồm 5000đ tiền hộp )', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085663, 'name': 'Bún Ốc Nhỏ + Sườn', 'price': 55000, 'rawPrice': 55000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-suon-0-1701233197', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-suon-0-1701233197'], 'description': '( Đã bao gồm 5000đ tiền hộp )', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085660, 'name': 'Bún Ốc Nhỏ + Sườn + Bò', 'price': 60000, 'rawPrice': 60000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-suon-bo-0-1701233669', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-nho-suon-bo-0-1701233669'], 'description': '', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085664, 'name': 'Bún Ốc To', 'price': 55000, 'rawPrice': 55000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-0-1701232208', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-0-1701232208'], 'description': '( Đã bao gồm 5000đ tiền hộp )', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085673, 'name': 'Bún Ốc To + Bò', 'price': 55000, 'rawPrice': 55000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-bo-0-1701232441', 'images': ['https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-bo-0-1701232441'], 'description': '( Đã bao gồm 5000đ tiền hộp )', 'customs': [], 'soldOut': False, 'isAppliedFixedPricePromotionCampaign': False, 'isAvailableForSale': True}, {'id': 74085672, 'name': 'Bún Ốc To + Sườn', 'price': 60000, 'rawPrice': 60000, 'image': 'https://tea-3.lozi.vn/v1/ship/resized/bun-oc-suon-co-sau-quan-hai-ba-trung-ha-noi-1701161402947255685-bun-oc-to-suon-0-1701233179', 'images': ['https://tea-3.lozi.vn/v1/ship/resize ...
#
# 9 slug :  bun-oc-suon-co-sau-tan-xuan-quan-bac-tu-liem-ha-noi-1701161616931845024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 31
#      29 print(i ,"slug : ", shop['slug'])
#      30 shop_info = get_shop_full_info(slug=shop['slug']) # lấy toàn bộ thông tin của 1 quán ăn theo thẻ slug
# ---> 31 menu_info = get_menu_info(slug=shop['slug']) # lấy toàn thông tin của menu
#      32 print("shop_info : ", shop_info)
#      33 print("menu info : ", menu_info)
#
# Cell In[33], line 24, in get_menu_info(slug)
#       4 payload = {}
#       5 headers = {
#       6 'accept': '*/*',
#       7 'accept-language': 'vi_VN',
#    (...)
#      21 'x-lozi-client': '1'
#      22 }
# ---> 24 response = requests.request("GET", url, headers=headers, data=payload)
#      26 data_json = json.loads(response.text)
#      27 return data_json['data']
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\setting\Anaconda3\envs\sic\lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File d:\setting\Anaconda3\envs\sic\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File d:\setting\Anaconda3\envs\sic\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File d:\setting\Anaconda3\envs\sic\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File d:\setting\Anaconda3\envs\sic\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File d:\setting\Anaconda3\envs\sic\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File d:\setting\Anaconda3\envs\sic\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# using time module
import time
 
# ts stores the time in seconds
ts = time.time()
 
# print the current timestamp
print(ts)
# Out:
# 1720342768.8046455

# %% [markdown]
# # Kafka

# %%
import numpy as np

# %%
from kafka import KafkaConsumer, TopicPartition

# %%
consumer = KafkaConsumer(bootstrap_servers="localhost:9092")
consumer.subscribe('sic-kafka')

# %%
# last message
partition = TopicPartition('sic-kafka', 0)
end_offset = consumer.end_offsets([partition])
consumer.seek(partition,list(end_offset.values())[0]-1)

for m in consumer:
  print(m.value)

# %%
# stream consumer
for msg in consumer:
    print(msg.value)

# %%
# producer
from kafka import KafkaProducer

# %%
producer = KafkaProducer(bootstrap_servers='localhost:9092')

# %%
for i in range(10):
    msg = f"message {i} : Xin Chao, Toi la HaUIer"
    producer.send("sic-kafka", bytes(msg, 'utf-8'))

# %%
# %pwd
# Out:
# 'd:\\haui\\SIC\\sic\\bigdata'
